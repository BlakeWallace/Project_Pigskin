# %% [markdown]
# ## Exploring the school index info to generate historical and official win-loss percentage data.

# %% [markdown]
# ### Data Sources
#
# 1. [Sports Reference CFB School Index](https://www.sports-reference.com/cfb/schools/)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# Inport the data.

# %%
data = pd.read_csv('Data/school_index_sr.csv')

# %% [markdown]
# Some general info about the dataset.

# %%
print(data.shape)
print(data.isnull().sum())
data.head()
# Out:
# (298, 20)
# Rk          0
# School      0
# From        0
# To          0
# Yrs         0
# G           0
# W           0
# L           0
# T           0
# Pct         0
# G.1         0
# W.1         0
# L.1         0
# T.1         0
# Pct.1     135
# SRS         0
# SOS         0
# AP          0
# CC          0
# Notes     231
# dtype: int64
#    Rk               School  From    To  Yrs     G    W    L   T    Pct  G.1  \
# 0   1            Air Force  1957  2019   63   705  384  325  12  0.541   26
# 1   2                Akron  1975  2019   34   383  150  230   3  0.396    3
# 2   3              Alabama  1902  2019  116  1213  919  303  42  0.744   70
# 3   4  Alameda Coast Guard  1943  1944    2    15    8    4   3  0.633    0
# 4   5         Alcorn State  1977  1977    1    11    3    8   0  0.273    0
#
#    W.1  L.1  T.1  Pct.1    SRS   SOS  AP  CC  \
# 0   12   13    1  0.481   1.02 -0.57   6   3
# 1    1    2    0  0.500 -11.46 -7.08   0   1
# 2   41   26    3  0.596  13.44  4.15  56  26
# 3    0    0    0    NaN  -0.16 -5.13   0   0
# 4    0    0    0    NaN -17.10 -9.19   0   0
#
#                                    Notes
# 0                                    NaN
# 1                                    NaN
# 2  record adjusted to 890-312-41 by NCAA
# 3                                    NaN
# 4                                    NaN

# %% [markdown]
# Two things stand out to us immediately.  First, some of these schools are only represented from past seasons, but are not surrently competing.  See the feature column `'To'`.  We will filter our data to keep down to only teams competing in the updcoming season.  The other thing to note is that the information in the Win-Loss-Tie columns, along with the win percentage are not all officially accurate.  The NCAA sometimes, after reviewing a teams eligibality, decides that a teams wins must be [forfieted or vacated](https://www.sports-reference.com/cfb/friv/forfeits.html).  So, officially, there is an adjusted win percentage, while the one displayed in the column labeled `'Pct'` is more of an on the day of win percentage.
#
# In what follows we will first remove the teams that are not currently competing.  Then we will create several new features for displaying the official win-loss-tie and win percentage data, taking into account the information in the `'Notes'` feature.

# %%
# defining the stuff_to_keep dataset that we will transform below.
stuff_to_keep = data[data['To'] == 2019]

# %%
print(stuff_to_keep.shape)
print(stuff_to_keep.isnull().sum())
stuff_to_keep.head()
# Out:
# (130, 20)
# Rk         0
# School     0
# From       0
# To         0
# Yrs        0
# G          0
# W          0
# L          0
# T          0
# Pct        0
# G.1        0
# W.1        0
# L.1        0
# T.1        0
# Pct.1      5
# SRS        0
# SOS        0
# AP         0
# CC         0
# Notes     67
# dtype: int64
#    Rk             School  From    To  Yrs     G    W    L   T    Pct  G.1  \
# 0   1          Air Force  1957  2019   63   705  384  325  12  0.541   26
# 1   2              Akron  1975  2019   34   383  150  230   3  0.396    3
# 2   3            Alabama  1902  2019  116  1213  919  303  42  0.744   70
# 7   8  Appalachian State  1972  2019   16   174   97   72   5  0.572    4
# 8   9            Arizona  1931  2019   86   920  486  422  23  0.534   20
#
#    W.1  L.1  T.1  Pct.1    SRS   SOS  AP  CC  \
# 0   12   13    1  0.481   1.02 -0.57   6   3
# 1    1    2    0  0.500 -11.46 -7.08   0   1
# 2   41   26    3  0.596  13.44  4.15  56  26
# 7    4    0    0  1.000  -3.06 -6.96   0   1
# 8    9   10    1  0.500   1.72  0.59   8   6
#
#                                    Notes
# 0                                    NaN
# 1                                    NaN
# 2  record adjusted to 890-312-41 by NCAA
# 7                                    NaN
# 8                                    NaN

# %% [markdown]
# Notice that there are 67 nulls in the `'Notes'` feature.  Let's explore the different types of information that are housed in this column.

# %%
# first, extend the number of displayed rows
pd.options.display.max_rows = 200

# %%
# now, reset the index
stuff_to_keep.reset_index(inplace=True)
stuff_to_keep.head()
# Out:
#    index  Rk             School  From    To  Yrs     G    W    L   T  ...  \
# 0      0   1          Air Force  1957  2019   63   705  384  325  12  ...
# 1      1   2              Akron  1975  2019   34   383  150  230   3  ...
# 2      2   3            Alabama  1902  2019  116  1213  919  303  42  ...
# 3      7   8  Appalachian State  1972  2019   16   174   97   72   5  ...
# 4      8   9            Arizona  1931  2019   86   920  486  422  23  ...
#
#    G.1  W.1  L.1  T.1  Pct.1    SRS   SOS  AP  CC  \
# 0   26   12   13    1  0.481   1.02 -0.57   6   3
# 1    3    1    2    0  0.500 -11.46 -7.08   0   1
# 2   70   41   26    3  0.596  13.44  4.15  56  26
# 3    4    4    0    0  1.000  -3.06 -6.96   0   1
# 4   20    9   10    1  0.500   1.72  0.59   8   6
#
#                                    Notes
# 0                                    NaN
# 1                                    NaN
# 2  record adjusted to 890-312-41 by NCAA
# 3                                    NaN
# 4                                    NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# Now, drop the unneeded `'index'` column.

# %%
stuff_to_keep.drop(columns='index', axis=1, inplace=True)
stuff_to_keep.head()
# Out:
# /Users/blakewallace/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#    Rk             School  From    To  Yrs     G    W    L   T    Pct  G.1  \
# 0   1          Air Force  1957  2019   63   705  384  325  12  0.541   26
# 1   2              Akron  1975  2019   34   383  150  230   3  0.396    3
# 2   3            Alabama  1902  2019  116  1213  919  303  42  0.744   70
# 3   8  Appalachian State  1972  2019   16   174   97   72   5  0.572    4
# 4   9            Arizona  1931  2019   86   920  486  422  23  0.534   20
#
#    W.1  L.1  T.1  Pct.1    SRS   SOS  AP  CC  \
# 0   12   13    1  0.481   1.02 -0.57   6   3
# 1    1    2    0  0.500 -11.46 -7.08   0   1
# 2   41   26    3  0.596  13.44  4.15  56  26
# 3    4    0    0  1.000  -3.06 -6.96   0   1
# 4    9   10    1  0.500   1.72  0.59   8   6
#
#                                    Notes
# 0                                    NaN
# 1                                    NaN
# 45   record adjusted to 472-600-34 by NCAA
# 47   record adjusted to 492-551-36 by NCAA
# 49    record adjusted to 205-295-5 by NCAA
# 50    record adjusted to 230-210-7 by NCAA
# 52    record adjusted to 351-296-7 by NCAA
# 53   record adjusted to 769-400-47 by NCAA
# 57    record adjusted to 315-337-8 by NCAA
# 59   record adjusted to 351-277-15 by NCAA
# 61   record adjusted to 573-382-30 by NCAA
# 64   record adjusted to 555-566-36 by NCAA
# 65   record adjusted to 631-529-50 by NCAA
# 67   record adjusted to 863-363-37 by NCAA
# 69    record adjusted to 161-314-3 by NCAA
# 71   record adjusted to 315-578-14 by NCAA
# 72   record adjusted to 631-514-48 by NCAA
# 74   record adjusted to 261-327-11 by NCAA
# 76   record adjusted to 536-658-40 by NCAA
# 77   record adjusted to 820-310-33 by NCAA
# 79   record adjusted to 791-257-36 by NCAA
# 83   record adjusted to 612-501-34 by NCAA
# 84   record adjusted to 580-454-34 by NCAA
# 85   record adjusted to 462-562-36 by NCAA
# 87   record adjusted to 676-481-37 by NCAA
# 88   record adjusted to 604-562-48 by NCAA
# 89   record adjusted to 465-615-32 by NCAA
# 90   record adjusted to 479-477-22 by NCAA
# 91    record adjusted to 324-260-8 by NCAA
# 92   record adjusted to 334-417-14 by NCAA
# 93   record adjusted to 487-536-54 by NCAA
# 95   record adjusted to 576-545-41 by NCAA
# 97    record adjusted to 360-278-6 by NCAA
# 99   record adjusted to 663-490-41 by NCAA
# 100  record adjusted to 317-411-26 by NCAA
# 101  record adjusted to 814-372-50 by NCAA
# 102  record adjusted to 858-360-31 by NCAA
# 104  record adjusted to 630-526-50 by NCAA
# 107   record adjusted to 385-261-8 by NCAA
# 109  record adjusted to 503-623-35 by NCAA
# 113  record adjusted to 576-391-31 by NCAA
# 114  record adjusted to 741-305-40 by NCAA
# 116  record adjusted to 509-512-28 by NCAA
# 119  record adjusted to 545-596-43 by NCAA
# 121  record adjusted to 709-455-44 by NCAA
# 123  record adjusted to 632-418-32 by NCAA
# 124  record adjusted to 475-518-38 by NCAA
# 127   record adjusted to 331-299-7 by NCAA
# 128  record adjusted to 701-489-52 by NCAA
# 129  record adjusted to 508-559-26 by NCAA

# %% [markdown]
# Here is a look at how the win percentage is calculated.  Note that each tie is counted as a half win.

# %%
(2*919+42)/(2*(919+303+42))
# Out:
# 0.7436708860759493

# %%
(2*890+41)/(2*(890+312+41))
# Out:
# 0.7325020112630732

# %%
stuff_to_keep['Notes'][2:3]
# Out:
# 2    record adjusted to 890-312-41 by NCAA
# Name: Notes, dtype: object

# %% [markdown]
# Now, we create a dictionary to hold the index and the official record.

# %%
dict_index_record = {}

for index, value in stuff_to_keep['Notes'].items():
    if type(value) == str:
#         print(index, value[19:29])
        dict_index_record[index] = value[19:29].split('-')
dict_index_record
#         win_loss_tie = value[19:29].split('-')
#         dict_win_loss_tie[index] = 
#         print(win_loss_tie)
# Out:
# {2: ['890', '312', '41'],
#  6: ['682', '480', '37'],
#  7: ['183', '236', '2 '],
#  9: ['744', '429', '42'],
#  11: ['584', '565', '40'],
#  17: ['568', '512', '31'],
#  24: ['516', '555', '31'],
#  27: ['321', '295', '3 '],
#  32: ['508', '235', '16'],
#  33: ['351', '250', '4 '],
#  37: ['728', '481', '40'],
#  39: ['429', '346', '14'],
#  41: ['460', '655', '38'],
#  42: ['620', '529', '34'],
#  43: ['512', '641', '45'],
#  45: ['472', '600', '34'],
#  47: ['492', '551', '36'],
#  49: ['205', '295', '5 '],
#  50: ['230', '210', '7 '],
#  52: ['351', '296', '7 '],
#  53: ['769', '400', '47'],
#  57: ['315', '337', '8 '],
#  59: ['351', '277', '15'],
#  61: ['573', '382', '30'],
#  64: ['555', '566', '36'],
#  65: ['631', '529', '50'],
#  67: ['863', '363', '37'],
#  69: ['161', '314', '3 '],
#  71: ['315', '578', '14'],
#  72: ['631', '514', '48'],
#  74: ['261', '327', '11'],
#  76: ['536', '658', '40'],
#  77: ['820', '310', '33'],
#  79: ['791', '257', '36'],
#  83: ['612', '501', '34'],
#  84: ['580', '454', '34'],
#  85: ['462', '562', '36'],
#  87: ['676', '481', '37'],
#  88: ['604', '562', '48'],
#  89: ['465', '615', '32'],
#  90: ['479', '477', '22'],
#  91: ['324', '260', '8 '],
#  92: ['334', '417', '14'],
#  93: ['487', '536', '54'],
#  95: ['576', '545', '41'],
#  97: ['360', '278', '6 '],
#  99: ['663', '490', '41'],
#  100: ['317', '411', '26'],
#  101: ['814', '372', '50'],
#  102: ['858', '360', '31'],
#  104: ['630', '526', '50'],
#  107: ['385', '261', '8 '],
#  109: ['503', '623', '35'],
#  113: ['576', '391', '31'],
#  114: ['741', '305', '40'],
#  116: ['509', '512', '28'],
#  119: ['545', '596', '43'],
#  121: ['709', '455', '44'],
#  123: ['632', '418', '32'],
#  124: ['475', '518', '38'],
#  127: ['331', '299', '7 '],
#  128: ['701', '489', '52'],
#  129: ['508', '559', '26']}

# %% [markdown]
# Next, convert the values in each list to integer values (at the moment they are strings, which is indicated by the quotes around them).

# %%
for item in dict_index_record:
    for i in range(len(dict_index_record[item])):
        dict_index_record[item][i] = int(dict_index_record[item][i])
#     print(dict_index_record[item])
dict_index_record
# Out:
# {2: [890, 312, 41],
#  6: [682, 480, 37],
#  7: [183, 236, 2],
#  9: [744, 429, 42],
#  11: [584, 565, 40],
#  17: [568, 512, 31],
#  24: [516, 555, 31],
#  27: [321, 295, 3],
#  32: [508, 235, 16],
#  33: [351, 250, 4],
#  37: [728, 481, 40],
#  39: [429, 346, 14],
#  41: [460, 655, 38],
#  42: [620, 529, 34],
#  43: [512, 641, 45],
#  45: [472, 600, 34],
#  47: [492, 551, 36],
#  49: [205, 295, 5],
#  50: [230, 210, 7],
#  52: [351, 296, 7],
#  53: [769, 400, 47],
#  57: [315, 337, 8],
#  59: [351, 277, 15],
#  61: [573, 382, 30],
#  64: [555, 566, 36],
#  65: [631, 529, 50],
#  67: [863, 363, 37],
#  69: [161, 314, 3],
#  71: [315, 578, 14],
#  72: [631, 514, 48],
#  74: [261, 327, 11],
#  76: [536, 658, 40],
#  77: [820, 310, 33],
#  79: [791, 257, 36],
#  83: [612, 501, 34],
#  84: [580, 454, 34],
#  85: [462, 562, 36],
#  87: [676, 481, 37],
#  88: [604, 562, 48],
#  89: [465, 615, 32],
#  90: [479, 477, 22],
#  91: [324, 260, 8],
#  92: [334, 417, 14],
#  93: [487, 536, 54],
#  95: [576, 545, 41],
#  97: [360, 278, 6],
#  99: [663, 490, 41],
#  100: [317, 411, 26],
#  101: [814, 372, 50],
#  102: [858, 360, 31],
#  104: [630, 526, 50],
#  107: [385, 261, 8],
#  109: [503, 623, 35],
#  113: [576, 391, 31],
#  114: [741, 305, 40],
#  116: [509, 512, 28],
#  119: [545, 596, 43],
#  121: [709, 455, 44],
#  123: [632, 418, 32],
#  124: [475, 518, 38],
#  127: [331, 299, 7],
#  128: [701, 489, 52],
#  129: [508, 559, 26]}

# %% [markdown]
# Now, we take each record and create a dictionary that house the win-loss-tie data.

# %%
# sample code
lst1 = [4, 7, 2]
lst2 = [3,6, 5]

outcome = ['win', 'loss', 'tie']
inner_dict = {}
dict_prac = {}
lst = [lst1, lst2]
for thing in range(len(lst)): 
    for j in range(len(lst[thing])):
#         print(j)
        
        inner_dict[outcome[j]] = lst[thing][j]
    dict_prac[str(lst[thing])] = inner_dict
    inner_dict = {}
dict_prac
# Out:
# {'[4, 7, 2]': {'win': 4, 'loss': 7, 'tie': 2},
#  '[3, 6, 5]': {'win': 3, 'loss': 6, 'tie': 5}}

# %% [markdown]
# The next code block generates a dictionary housing the official win-loss-tie data in a dictionary, `dict_win_loss_tie`.

# %%
outcome = ['win', 'loss', 'tie']
inner_dict = {}
dict_win_loss_tie = {}

for thing in dict_index_record: 
    for j in range(len(dict_index_record[thing])):
#         print(j)
        
        inner_dict[outcome[j]] = dict_index_record[thing][j]
    dict_win_loss_tie[thing] = inner_dict
    inner_dict = {}
dict_win_loss_tie
# Out:
# {2: {'win': 890, 'loss': 312, 'tie': 41},
#  6: {'win': 682, 'loss': 480, 'tie': 37},
#  7: {'win': 183, 'loss': 236, 'tie': 2},
#  9: {'win': 744, 'loss': 429, 'tie': 42},
#  11: {'win': 584, 'loss': 565, 'tie': 40},
#  17: {'win': 568, 'loss': 512, 'tie': 31},
#  24: {'win': 516, 'loss': 555, 'tie': 31},
#  27: {'win': 321, 'loss': 295, 'tie': 3},
#  32: {'win': 508, 'loss': 235, 'tie': 16},
#  33: {'win': 351, 'loss': 250, 'tie': 4},
#  37: {'win': 728, 'loss': 481, 'tie': 40},
#  39: {'win': 429, 'loss': 346, 'tie': 14},
#  41: {'win': 460, 'loss': 655, 'tie': 38},
#  42: {'win': 620, 'loss': 529, 'tie': 34},
#  43: {'win': 512, 'loss': 641, 'tie': 45},
#  45: {'win': 472, 'loss': 600, 'tie': 34},
#  47: {'win': 492, 'loss': 551, 'tie': 36},
#  49: {'win': 205, 'loss': 295, 'tie': 5},
#  50: {'win': 230, 'loss': 210, 'tie': 7},
#  52: {'win': 351, 'loss': 296, 'tie': 7},
#  53: {'win': 769, 'loss': 400, 'tie': 47},
#  57: {'win': 315, 'loss': 337, 'tie': 8},
#  59: {'win': 351, 'loss': 277, 'tie': 15},
#  61: {'win': 573, 'loss': 382, 'tie': 30},
#  64: {'win': 555, 'loss': 566, 'tie': 36},
#  65: {'win': 631, 'loss': 529, 'tie': 50},
#  67: {'win': 863, 'loss': 363, 'tie': 37},
#  69: {'win': 161, 'loss': 314, 'tie': 3},
#  71: {'win': 315, 'loss': 578, 'tie': 14},
#  72: {'win': 631, 'loss': 514, 'tie': 48},
#  74: {'win': 261, 'loss': 327, 'tie': 11},
#  76: {'win': 536, 'loss': 658, 'tie': 40},
#  77: {'win': 820, 'loss': 310, 'tie': 33},
#  79: {'win': 791, 'loss': 257, 'tie': 36},
#  83: {'win': 612, 'loss': 501, 'tie': 34},
#  84: {'win': 580, 'loss': 454, 'tie': 34},
#  85: {'win': 462, 'loss': 562, 'tie': 36},
#  87: {'win': 676, 'loss': 481, 'tie': 37},
#  88: {'win': 604, 'loss': 562, 'tie': 48},
#  89: {'win': 465, 'loss': 615, 'tie': 32},
#  90: {'win': 479, 'loss': 477, 'tie': 22},
#  91: {'win': 324, 'loss': 260, 'tie': 8},
#  92: {'win': 334, 'loss': 417, 'tie': 14},
#  93: {'win': 487, 'loss': 536, 'tie': 54},
#  95: {'win': 576, 'loss': 545, 'tie': 41},
#  97: {'win': 360, 'loss': 278, 'tie': 6},
#  99: {'win': 663, 'loss': 490, 'tie': 41},
#  100: {'win': 317, 'loss': 411, 'tie': 26},
#  101: {'win': 814, 'loss': 372, 'tie': 50},
#  102: {'win': 858, 'loss': 360, 'tie': 31},
#  104: {'win': 630, 'loss': 526, 'tie': 50},
#  107: {'win': 385, 'loss': 261, 'tie': 8},
#  109: {'win': 503, 'loss': 623, 'tie': 35},
#  113: {'win': 576, 'loss': 391, 'tie': 31},
#  114: {'win': 741, 'loss': 305, 'tie': 40},
#  116: {'win': 509, 'loss': 512, 'tie': 28},
#  119: {'win': 545, 'loss': 596, 'tie': 43},
#  121: {'win': 709, 'loss': 455, 'tie': 44},
#  123: {'win': 632, 'loss': 418, 'tie': 32},
#  124: {'win': 475, 'loss': 518, 'tie': 38},
#  127: {'win': 331, 'loss': 299, 'tie': 7},
#  128: {'win': 701, 'loss': 489, 'tie': 52},
#  129: {'win': 508, 'loss': 559, 'tie': 26}}

# %% [markdown]
# From the above variable, `dict_win_loss_tie`, we create feature variables that capture the official `'adjusted'` outcomes.
