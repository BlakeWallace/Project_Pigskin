# %% [markdown]
# ## In this notebook we explore Notre Dame's historical statistics.

# %% [markdown]
# ### Sources include:
# 1. [Sports Reference's Notre Dame Historical Data](https://www.sports-reference.com/cfb/schools/notre-dame/)

# %% [markdown]
# ### Important Data we would like to use from this.
#
# 1. Historical Win Percentage - [Pct](#pct)
# 1. Number of Seasons - [seasons_count](#num_of_seasons)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
pd.options.display.max_rows = 150

# %%
ND_data = pd.read_csv("../Data/Notre_Dame_Historical_win-loss.csv")
ND_data
# Out:
#                                                     Rk    Year Conf     W  \
# 0                                                    1  2019.0  Ind   0.0
# 1                                                    2  2018.0  Ind  12.0
# 2                                                    3  2017.0  Ind  10.0
# 3                                                    4  2016.0  Ind   4.0
# 4                                                    5  2015.0  Ind  10.0
# 5                                                    6  2014.0  Ind   8.0
# 6                                                    7  2013.0  Ind   9.0
# 7                                                    8  2012.0  Ind  12.0
# 8                                                    9  2011.0  Ind   8.0
# 9                                                   10  2010.0  Ind   8.0
# 10                                                  11  2009.0  Ind   6.0
# 11                                                  12  2008.0  Ind   7.0
# ...

# %%
ND_data.drop(labels=[0,113,114,115], axis=0,inplace=True)

# %%
ND_data.dtypes
# Out:
# Rk            object
# Year         float64
# Conf          object
# W            float64
# L            float64
# T            float64
# Pct          float64
# SRS          float64
# SOS          float64
# AP Pre       float64
# AP High      float64
# AP Post      float64
# Coach(es)     object
# Bowl          object
# Notes         object
# dtype: object

# %%
np.average(ND_data['Pct'])
# Out:
# 0.7283303571428572

# %%
ND_data.describe()[['Pct']].T['mean']
# Out:
# Pct    0.72833
# Name: mean, dtype: float64

# %%
ND_data.isnull().sum()
# Out:
# Rk             0
# Year           0
# Conf           0
# W              0
# L              0
# T              0
# Pct            0
# SRS            0
# SOS            0
# AP Pre        57
# AP High       34
# AP Post       58
# Coach(es)      0
# Bowl          75
# Notes        110
# dtype: int64

# %%
ND_data.dropna().shape
# Out:
# (1, 15)

# %%
ND_data.shape
# Out:
# (112, 15)

# %% [markdown]
# <a id='pct'></a>

# %%
ND_data['Pct'].mean()
# Out:
# 0.7283303571428573

# %%
ND_data.columns
# Out:
# Index(['Rk', 'Year', 'Conf', 'W', 'L', 'T', 'Pct', 'SRS', 'SOS', 'AP Pre',
#        'AP High', 'AP Post', 'Coach(es)', 'Bowl', 'Notes'],
#       dtype='object')

# %% [markdown]
# <a id='num_of_seasons'></a>

# %%
ND_data['Year'].count()
# Out:
# 112

# %%
ND_data.describe()
# Out:
#               Year           W           L           T         Pct  \
# count   112.000000  112.000000  112.000000  112.000000  112.000000
# mean   1962.089286    7.508929    2.767857    0.294643    0.728330
# std      33.191650    2.189226    2.160172    0.495718    0.190713
# min    1899.000000    2.000000    0.000000    0.000000    0.200000
# 25%    1934.750000    6.000000    1.000000    0.000000    0.615000
# 50%    1962.500000    8.000000    2.000000    0.000000    0.750000
# 75%    1990.250000    9.000000    4.000000    1.000000    0.889000
# max    2018.000000   12.000000    9.000000    2.000000    1.000000
#
#               SRS         SOS     AP Pre    AP High    AP Post
# count  112.000000  112.000000  55.000000  78.000000  54.000000
# mean    14.735893    6.147679   9.181818   5.256410   7.944444
# std      7.503168    4.450030   6.286643   5.260576   5.880626
# min     -5.030000   -7.180000   1.000000   1.000000   1.000000
# ...
